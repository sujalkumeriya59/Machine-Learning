# %% [markdown]
# <a href="https://colab.research.google.com/github/sujalkumeriya59/Machine-Learning/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

import pandas as pd

# Step 1: Import sales data from a CSV file into a DataFrame
# Update the file path with the correct location of your sales data CSV file
file_path = "/sales_data_sample.csv"   # or the full correct path if it's in a different directory
df = pd.read_csv(file_path, encoding='latin-1')

# Display the first few rows of the DataFrame
print("Initial DataFrame:")
print(df.head())

# Step 2: Perform basic data cleaning (e.g., handle missing values)
# Example: Fill missing 'SalesAmount' with the mean value
# Assuming 'SALES' is the actual column name for sales amount (replace with the correct name from the output above)
sales_amount_column = 'SALES'
df[sales_amount_column].fillna(df[sales_amount_column].mean(), inplace=True)

tax_rate = 0.05  # 5% sales tax rate
df['SalesTax'] = df[sales_amount_column] * tax_rate # Use the correct column name here as well

# Step 2: Perform basic data cleaning (e.g., handle missing values)
df[sales_amount_column].fillna(df[sales_amount_column].mean(), inplace=True)

# Display the DataFrame after cleaning
print("\nDataFrame after cleaning:")
print(df.head())

# Step 3: Add a new column for Sales Tax (e.g., 5% of SalesAmount)
tax_rate = 0.05  # 5% sales tax rate
df['SalesTax'] = df[sales_amount_column] * tax_rate

# Display the updated DataFrame with the new column
print("\nDataFrame after adding Sales Tax:")
print(df.head())

# Step 4: Export the updated DataFrame to a new CSV file
output_file_path = 'updated_sales_data.csv'  # Replace with your desired output file path
df.to_csv(output_file_path, index=False)

print(f"\nUpdated data has been exported to '{output_file_path}'")
print("Initial DataFrame:")
print(df.head())

# Step 2: Perform basic data cleaning (e.g., handle missing values)
# Example: Fill missing 'SalesAmount' with the mean value
df[sales_amount_column] = df[sales_amount_column].fillna(df[sales_amount_column].mean())

# Display the DataFrame after cleaning
print("\nDataFrame after cleaning:")
print(df.head())

# Step 3: Add a new column for Sales Tax (e.g., 5% of SalesAmount)
tax_rate = 0.05  # 5% sales tax rate
df['SalesTax'] = df[sales_amount_column] * 0.05  # Assuming 5% tax



# Display the updated DataFrame with the new column
print("\nDataFrame after adding Sales Tax:")
print(df.head())

# Step 4: Export the updated DataFrame to a new CSV file
output_file_path = 'updated_sales_data.csv'  # Replace with your desired output file path
df.to_csv(output_file_path, index=False)

print(f"\nUpdated data has been exported to '{output_file_path}'")
# Display the first few rows of the DataFrame
print("Initial DataFrame:")
print(df.head())

# Step 2: Perform basic data cleaning (e.g., handle missing values)
# Example: Fill missing 'SalesAmount' with the mean value
df[sales_amount_column].fillna(df[sales_amount_column].mean(), inplace=True)

# Display the DataFrame after cleaning
print("\nDataFrame after cleaning:")
print(df.head())

# Step 3: Add a new column for Sales Tax (e.g., 5% of SalesAmount)
tax_rate = 0.05  # 5% sales tax rate
df['SalesTax'] = df[sales_amount_column] * tax_rate

# Display the updated DataFrame with the new column
print("\nDataFrame after adding Sales Tax:")
print(df.head())

# Step 4: Export the updated DataFrame to a new CSV file
output_file_path = 'updated_sales_data.csv'  # Replace with your desired output file path
df.to_csv(output_file_path, index=False)

print(f"\nUpdated data has been exported to '{output_file_path}'")
print("Initial DataFrame:")
print(df.head())

# Step 2: Perform basic data cleaning (e.g., handle missing values)
# Example: Fill missing 'SalesAmount' with the mean value
df[sales_amount_column].fillna(df[sales_amount_column].mean(), inplace=True)

# Display the DataFrame after cleaning
print("\nDataFrame after cleaning:")
print(df.head())

# Step 3: Add a new column for Sales Tax (e.g., 5% of SalesAmount)
tax_rate = 0.05  # 5% sales tax rate
df['SalesTax'] = df[sales_amount_column] * tax_rate

# Display the updated DataFrame with the new column
print("\nDataFrame after adding Sales Tax:")
print(df.head())

# Step 4: Export the updated DataFrame to a new CSV file
output_file_path = 'updated_sales_data.csv'  # Replace with your desired output file path
df.to_csv(output_file_path, index=False)

print(f"\nUpdated data has been exported to '{output_file_path}'")
# Out:
# Initial DataFrame:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...
